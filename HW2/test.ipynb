# %%
import numpy as np
#import seaborn
from matplotlib import pyplot as plt
plt.xlabel("batch size")
plt.ylabel("Accuracy")

plt.plot([1,3, 5,10,15,20,25,30,35,50,100,200,300,500],
         [0.802, 0.795,0.789,0.781,0.787,0.781,0.782,0.781,0.778,0.783,0.78 ,0.782,0.777,0.778],'-o')
#, label='test accuracy')

#plt.legend(loc='lower right' )

#plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
a = np.array([[1,0],[0,1], [0,1]])
print(a.shape)
b = [1,2]
c = a[b,:]
print(c.shape)
# Out:
# (3, 2)
# (2, 2)
